# %%
from google.colab import drive
import pandas as pd

# %%
# Mounting the drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Object classification

from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
#from keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import load_img, img_to_array

model = VGG16()

image = load_img('/content/drive/MyDrive/ESRGAN/LR/Test20.png', target_size=(224, 224))
image = img_to_array(image)
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
image = preprocess_input(image)

prediction = model.predict(image)
labels = decode_predictions(prediction)
print('%s (%.2f%%)' % (labels[0][0][1], labels[0][0][2]*100))
print('%s (%.2f%%)' % (labels[0][1][1], labels[0][1][2]*100))
print('%s (%.2f%%)' % (labels[0][2][1], labels[0][2][2]*100))
# Out:
# 1/1 [==============================] - 0s 126ms/step
# breakwater (12.37%)
# beacon (5.89%)
# dome (5.07%)

# %%
# Testing ESRGAN model 

# %run /content/drive/MyDrive/ESRGAN/test.py

# %%
# Training the model

# %run /content/drive/MyDrive/ESRGAN/training/BasicSR-lite/codes/train.py -opt /content/drive/MyDrive/ESRGAN/training/BasicSR-lite/codes/options/train/train_template.yml
# Out:
# INFO:base:Path already exists. Rename it to [/content/drive/MyDrive/ESRGAN/training/BasicSR-lite/experiments/4x_template_archived_221216-085637]
# 22-12-16 08:56:37.073 - INFO: Path already exists. Rename it to [/content/drive/MyDrive/ESRGAN/training/BasicSR-lite/experiments/4x_template_archived_221216-085637]
# 22-12-16 08:56:37.073 - INFO: Path already exists. Rename it to [/content/drive/MyDrive/ESRGAN/training/BasicSR-lite/experiments/4x_template_archived_221216-085637]
# INFO:base:  name: 4x_template
#   use_tb_logger: False
#   model: srragan
#   scale: 4
#   batch_multiplier: 1
#   gpu_ids: [0]
#   datasets:[
#     train:[
#       name: Dataset
#       mode: LRHROTF
#       dataroot_HR: /content/drive/MyDrive/ESRGAN/training/BasicSR-lite/datasets/train/HR
#       dataroot_LR: /content/drive/MyDrive/ESRGAN/training/BasicSR-lite/datasets/train/LR
#       subset_file: None
#       use_shuffle: True
#       n_workers: 4
#       batch_size: 8
#       HR_size: 128
# ...
